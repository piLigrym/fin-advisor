# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv('financial_data.csv')
df
# Out:
#        total_income  total_expenses               income_source    food  \
# 0            480332          297030               Wage/Salaries  117848
# 1            198235          184888               Wage/Salaries   67766
# 2            189322          175402               Wage/Salaries   94625
# 3            152883          110091               Wage/Salaries   73326
# 4            171152          113258     Other sources of Income   67348
# ...             ...             ...                         ...     ...
# 24948        257600          249079               Wage/Salaries  127422
# 24949        382800          345866               Wage/Salaries  145253
# 24950        130950          101692               Wage/Salaries   76933
# 24951        166600          161104     Other sources of Income   90786
# 24952        133171          123607  Enterpreneurial Activities   45882
#
#        hospitality  alcohol  tobacco  clothing  public_utilities  medical  \
# ...

# %%
X = df[['total_income', 'total_expenses','food','hospitality','alcohol','tobacco','clothing',
        'public_utilities','medical','transport','communication','education','others','special','gardening','saving']]
y = df['min_invest']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r2}')
# Out:
# Mean Squared Error: 23165759.198682543
# R^2 Score: 0.9896653988144548

# %%
new_data = {
    'total_income': [480332],      	
    'total_expenses': [297030],
    'food': [117848],
    'hospitality': [3000],
    'alcohol': [0],
    'tobacco': [0],
    'clothing': [4607],
    'public_utilities': [63636],
    'medical': [3457],
    'transport': [4776],
    'communication': [2880],  
    'education': [36200],
    'others': [34056],
    'special': [7200],
    'gardening': [19370],
    'saving': [197112]         
}

new_df = pd.DataFrame(new_data)
predicted_min_invest = model.predict(new_df)
print(f'Min invest sum: {predicted_min_invest[0]}')
# Out:
# Min invest sum: 31367.08567463173

# %%
import joblib
joblib.dump(model, 'model_min_invest.joblib')
# Out:
# ['model_min_invest.joblib']
